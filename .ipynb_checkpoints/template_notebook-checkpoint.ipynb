# %%
# !java -version
# Out:
# openjdk version "17.0.19" 2026-04-21
# OpenJDK Runtime Environment Temurin-17.0.19+10 (build 17.0.19+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.19+10 (build 17.0.19+10, mixed mode)

# %% [markdown]
# # Template Quest Notebook

# %%
# Import neccessary modules, add to this cell as needed
# Provided PySpark examples
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pyspark.sql.functions as F

# %% [markdown]
# ## Part 1: Load the Sample Dataset

# %% [markdown]
# ### Note
# I thought I'd leave in working steps to show process but I've commented out **print**s and **show**s to save clutter

# %%
# Initiate a new Spark session and set the case sensitivity option
spark = (
    SparkSession.builder
        .appName("cyberquest")
        .getOrCreate()
)
spark.conf.set("spark.sql.caseSensitive", True)

# %%
# TODO: Load the raw data
#    - read from relative path
data_file = 'data/sysmon_spearphish_cribl.json'
df_bronze = spark.read.json(data_file)
df_bronze.show(10, truncate = False)
# Out:
# +----------------------------------------------+-----------+---------+-------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+------------------------------------+------------+---------------------------------------------------+
# |Computer                                      |Description|EventCode|User               |_raw                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |_time           |cribl_breaker|cribl_pipe                          |host        |source                                             |
# +----------------------------------------------+-----------+---------+-------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+------------------------------------+------------+---------------------------------------------------+
# |win-host-ctus-attack-range-212                |NULL       |23       |NT AUTHORITY\SYSTEM|{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"5","Level":"4","Task":"23","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.593519900Z'","EventRecordID":"320271","ProcessID":"'1912'","ThreadID":"'2628'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.591","ProcessGuid":"{72106695-9B97-63D3-6D00-00000000BD02}","ProcessId":"3764","Image":"C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-winevtlog.exe","TargetFilename":"C:\\Program Files\\SplunkUniversalForwarder\\var\\lib\\splunk\\modinputs\\WinEventLog\\Microsoft-Windows-Sysmon_Operational","Hashes":"MD5=5A621B8FAD832764B794B8E91043F993,SHA256=CA62C8E5D89362086534735B3AC31C9FB599BDA52534E770D2AA158D64F50BFC,IMPHASH=00000000000000000000000000000000","IsExecutable":"false","Archived":"true"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |1.674818387593E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |23       |NT AUTHORITY\SYSTEM|{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"5","Level":"4","Task":"23","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.419174000Z'","EventRecordID":"446583","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.410","ProcessGuid":"{45AAC21C-9BAA-63D3-7B00-00000000BC02}","ProcessId":"3928","Image":"C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-winevtlog.exe","TargetFilename":"C:\\Program Files\\SplunkUniversalForwarder\\var\\lib\\splunk\\modinputs\\WinEventLog\\Microsoft-Windows-Sysmon_Operational","Hashes":"MD5=7023EAC74833A625AD1FF676654E00E1,SHA256=7F7702B9A401BCBE13BE0B60F432BDCCCBF33CBA05F6B0BFFA037951AAE6EFBB,IMPHASH=00000000000000000000000000000000","IsExecutable":"false","Archived":"true"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |1.674818387419E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-host-ctus-attack-range-212                |NULL       |23       |NT AUTHORITY\SYSTEM|{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"5","Level":"4","Task":"23","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.009197600Z'","EventRecordID":"320270","ProcessID":"'1912'","ThreadID":"'2628'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.008","ProcessGuid":"{72106695-9B85-63D3-1B00-00000000BD02}","ProcessId":"1880","Image":"C:\\Program Files\\Amazon\\SSM\\amazon-ssm-agent.exe","TargetFilename":"C:\\ProgramData\\Amazon\\SSM\\InstanceData\\i-0f154ddf1aa5a8e8d\\channels\\health\\surveyor-20230127093814-099","Hashes":"MD5=97EF2A570B75C4F95FC69B0D09A2E2A2,SHA256=11396EA313B0ED7E3228C4FA92ABE9D836DB8F416A7A8A28ACC77133025082E7,IMPHASH=00000000000000000000000000000000","IsExecutable":"false","Archived":"true"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |1.674818387009E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.249728700Z'","EventRecordID":"446582","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.238","SourceProcessGUID":"{45AAC21C-B353-63D3-A903-00000000BC02}","SourceProcessId":"6048","SourceThreadId":"3292","SourceImage":"C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe","TargetProcessGUID":"{45AAC21C-9B96-63D3-2F00-00000000BC02}","TargetProcessId":"2816","TargetImage":"C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunkd.exe","GrantedAccess":"0x101400","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\System32\\KERNELBASE.dll+2c44d|C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe+6ae795|C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe+6ae2c6|C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe+643d8|C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe+65dfc|C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe+9dcf50|C:\\Windows\\System32\\KERNEL32.DLL+84d4|C:\\Windows\\SYSTEM32\\ntdll.dll+51791"}                                                                                                                    |1.674818387249E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.069349900Z'","EventRecordID":"446581","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.061","SourceProcessGUID":"{45AAC21C-9B98-63D3-3600-00000000BC02}","SourceProcessId":"3136","SourceThreadId":"3156","SourceImage":"C:\\Windows\\system32\\conhost.exe","TargetProcessGUID":"{45AAC21C-B353-63D3-A903-00000000BC02}","TargetProcessId":"6048","TargetImage":"C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe","GrantedAccess":"0x1fffff","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\SYSTEM32\\ConhostV2.dll+5ca7|C:\\Windows\\SYSTEM32\\ConhostV2.dll+774b|C:\\Windows\\SYSTEM32\\ConhostV2.dll+a8df|C:\\Windows\\System32\\KERNEL32.DLL+84d4|C:\\Windows\\SYSTEM32\\ntdll.dll+51791"}                                                                                                                                                                                                                                                                                                                                                                                                                                             |1.674818387069E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.068178400Z'","EventRecordID":"446580","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.061","SourceProcessGUID":"{45AAC21C-9B85-63D3-0C00-00000000BC02}","SourceProcessId":"836","SourceThreadId":"5472","SourceImage":"C:\\Windows\\system32\\svchost.exe","TargetProcessGUID":"{45AAC21C-9B96-63D3-2C00-00000000BC02}","TargetProcessId":"2776","TargetImage":"C:\\Windows\\sysmon64.exe","GrantedAccess":"0x1400","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\System32\\KERNELBASE.dll+5ea44|c:\\windows\\system32\\lsm.dll+fd18|C:\\Windows\\System32\\RPCRT4.dll+7b183|C:\\Windows\\System32\\RPCRT4.dll+d5bc1|C:\\Windows\\System32\\RPCRT4.dll+538bc|C:\\Windows\\System32\\RPCRT4.dll+35824|C:\\Windows\\System32\\RPCRT4.dll+3473d|C:\\Windows\\System32\\RPCRT4.dll+34feb|C:\\Windows\\System32\\RPCRT4.dll+20ddc|C:\\Windows\\System32\\RPCRT4.dll+2125c|C:\\Windows\\System32\\RPCRT4.dll+106bc|C:\\Windows\\System32\\RPCRT4.dll+11f1b|C:\\Windows\\System32\\RPCRT4.dll+1a50a|C:\\Windows\\SYSTEM32\\ntdll.dll+1d35e|C:\\Windows\\SYSTEM32\\ntdll.dll+1ecc9|C:\\Windows\\System32\\KERNEL32.DLL+84d4|C:\\Windows\\SYSTEM32\\ntdll.dll+51791"} |1.674818387068E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.068061300Z'","EventRecordID":"446579","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.061","SourceProcessGUID":"{45AAC21C-9B85-63D3-0C00-00000000BC02}","SourceProcessId":"836","SourceThreadId":"5472","SourceImage":"C:\\Windows\\system32\\svchost.exe","TargetProcessGUID":"{45AAC21C-9B96-63D3-2C00-00000000BC02}","TargetProcessId":"2776","TargetImage":"C:\\Windows\\sysmon64.exe","GrantedAccess":"0x1400","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\System32\\KERNELBASE.dll+5ea44|c:\\windows\\system32\\lsm.dll+11aad|C:\\Windows\\System32\\RPCRT4.dll+7b183|C:\\Windows\\System32\\RPCRT4.dll+d5bc1|C:\\Windows\\System32\\RPCRT4.dll+538bc|C:\\Windows\\System32\\RPCRT4.dll+35824|C:\\Windows\\System32\\RPCRT4.dll+3473d|C:\\Windows\\System32\\RPCRT4.dll+34feb|C:\\Windows\\System32\\RPCRT4.dll+20ddc|C:\\Windows\\System32\\RPCRT4.dll+2125c|C:\\Windows\\System32\\RPCRT4.dll+106bc|C:\\Windows\\System32\\RPCRT4.dll+11f1b|C:\\Windows\\System32\\RPCRT4.dll+1a50a|C:\\Windows\\SYSTEM32\\ntdll.dll+1d35e|C:\\Windows\\SYSTEM32\\ntdll.dll+1ecc9|C:\\Windows\\System32\\KERNEL32.DLL+84d4|C:\\Windows\\SYSTEM32\\ntdll.dll+51791"}|1.674818387068E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.067948300Z'","EventRecordID":"446578","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.061","SourceProcessGUID":"{45AAC21C-9B85-63D3-0C00-00000000BC02}","SourceProcessId":"836","SourceThreadId":"5472","SourceImage":"C:\\Windows\\system32\\svchost.exe","TargetProcessGUID":"{45AAC21C-9B96-63D3-2C00-00000000BC02}","TargetProcessId":"2776","TargetImage":"C:\\Windows\\sysmon64.exe","GrantedAccess":"0x1400","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\System32\\KERNELBASE.dll+5ea44|c:\\windows\\system32\\lsm.dll+11058|C:\\Windows\\System32\\RPCRT4.dll+7b183|C:\\Windows\\System32\\RPCRT4.dll+d5bc1|C:\\Windows\\System32\\RPCRT4.dll+538bc|C:\\Windows\\System32\\RPCRT4.dll+35824|C:\\Windows\\System32\\RPCRT4.dll+3473d|C:\\Windows\\System32\\RPCRT4.dll+34feb|C:\\Windows\\System32\\RPCRT4.dll+20ddc|C:\\Windows\\System32\\RPCRT4.dll+2125c|C:\\Windows\\System32\\RPCRT4.dll+106bc|C:\\Windows\\System32\\RPCRT4.dll+11f1b|C:\\Windows\\System32\\RPCRT4.dll+1a50a|C:\\Windows\\SYSTEM32\\ntdll.dll+1d35e|C:\\Windows\\SYSTEM32\\ntdll.dll+1ecc9|C:\\Windows\\System32\\KERNEL32.DLL+84d4|C:\\Windows\\SYSTEM32\\ntdll.dll+51791"}|1.674818387067E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.067824600Z'","EventRecordID":"446577","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.061","SourceProcessGUID":"{45AAC21C-9B85-63D3-0C00-00000000BC02}","SourceProcessId":"836","SourceThreadId":"5472","SourceImage":"C:\\Windows\\system32\\svchost.exe","TargetProcessGUID":"{45AAC21C-9B96-63D3-2C00-00000000BC02}","TargetProcessId":"2776","TargetImage":"C:\\Windows\\sysmon64.exe","GrantedAccess":"0x1400","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\System32\\KERNELBASE.dll+5ea44|c:\\windows\\system32\\lsm.dll+12023|C:\\Windows\\System32\\RPCRT4.dll+7b183|C:\\Windows\\System32\\RPCRT4.dll+d5bc1|C:\\Windows\\System32\\RPCRT4.dll+538bc|C:\\Windows\\System32\\RPCRT4.dll+35824|C:\\Windows\\System32\\RPCRT4.dll+3473d|C:\\Windows\\System32\\RPCRT4.dll+34feb|C:\\Windows\\System32\\RPCRT4.dll+20ddc|C:\\Windows\\System32\\RPCRT4.dll+2125c|C:\\Windows\\System32\\RPCRT4.dll+106bc|C:\\Windows\\System32\\RPCRT4.dll+11f1b|C:\\Windows\\System32\\RPCRT4.dll+1a50a|C:\\Windows\\SYSTEM32\\ntdll.dll+1d35e|C:\\Windows\\SYSTEM32\\ntdll.dll+1ecc9|C:\\Windows\\System32\\KERNEL32.DLL+84d4|C:\\Windows\\SYSTEM32\\ntdll.dll+51791"}|1.674818387067E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# |win-dc-ctus-attack-range-460.attackrange.local|NULL       |10       |NULL               |{"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"3","Level":"4","Task":"10","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.067693500Z'","EventRecordID":"446576","ProcessID":"'2776'","ThreadID":"'1288'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.061","SourceProcessGUID":"{45AAC21C-9B83-63D3-0500-00000000BC02}","SourceProcessId":"416","SourceThreadId":"384","SourceImage":"C:\\Windows\\system32\\csrss.exe","TargetProcessGUID":"{45AAC21C-B353-63D3-A903-00000000BC02}","TargetProcessId":"6048","TargetImage":"C:\\Program Files\\SplunkUniversalForwarder\\bin\\splunk-admon.exe","GrantedAccess":"0x1fffff","CallTrace":"C:\\Windows\\SYSTEM32\\ntdll.dll+a6154|C:\\Windows\\system32\\basesrv.DLL+2f47|C:\\Windows\\SYSTEM32\\CSRSRV.dll+5645|C:\\Windows\\SYSTEM32\\ntdll.dll+5179f"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1.674818387067E9|fallback     |Splunk_UF_Windows_XML_WEC_WEF_Sysmon|f2c75b47cbb7|/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|
# +----------------------------------------------+-----------+---------+-------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------------+------------------------------------+------------+---------------------------------------------------+
# only showing top 10 rows

# %%
#local copy of first three rows for a bit of manual exploration.
inspectionSample = df_bronze.take(3)
print(inspectionSample[2])
# Out:
# Row(Computer='win-host-ctus-attack-range-212', Description=None, EventCode='23', User='NT AUTHORITY\\SYSTEM', _raw='{"Name":"\'Microsoft-Windows-Sysmon\'","Guid":"\'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}\'","Version":"5","Level":"4","Task":"23","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"\'2023-01-27T11:19:47.009197600Z\'","EventRecordID":"320270","ProcessID":"\'1912\'","ThreadID":"\'2628\'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.008","ProcessGuid":"{72106695-9B85-63D3-1B00-00000000BD02}","ProcessId":"1880","Image":"C:\\\\Program Files\\\\Amazon\\\\SSM\\\\amazon-ssm-agent.exe","TargetFilename":"C:\\\\ProgramData\\\\Amazon\\\\SSM\\\\InstanceData\\\\i-0f154ddf1aa5a8e8d\\\\channels\\\\health\\\\surveyor-20230127093814-099","Hashes":"MD5=97EF2A570B75C4F95FC69B0D09A2E2A2,SHA256=11396EA313B0ED7E3228C4FA92ABE9D836DB8F416A7A8A28ACC77133025082E7,IMPHASH=00000000000000000000000000000000","IsExecutable":"false","Archived":"true"}', _time=1674818387.009, cribl_breaker='fallback', cribl_pipe='Splunk_UF_Windows_XML_WEC_WEF_Sysmon', host='f2c75b47cbb7', source='/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log')

# %%
# TODO: Parse the raw data into something relevant and usable
#   - make fields in _raw usable, flatten into 2D df. 
#      - [x] make rough schema of inner JSON, just useful looking fields.
#          - [x] if task 2 requires further fields or I miss any I can revisit here.
#      - [x] make copy of bronze_df with another column containing _raw as parsed json from rough schema.
#      - [x] select useful fields from parsed_raw as columns for silver_df.

rough_schema = StructType([
    StructField("UtcTime", StringType(), True),
    StructField("Image", StringType(), True),
    StructField("ProcessId", StringType(), True),
    StructField("CommandLine", StringType(), True),
    StructField("ParentImage", StringType(), True),
    StructField("TargetFilename", StringType(), True),
    StructField("SourceImage", StringType(), True),
    StructField("TargetImage", StringType(), True),
    StructField("QueryName", StringType(), True),
    StructField("Hashes", StringType(), True),
])

df_bronze_copy = df_bronze.withColumn(
    "raw_parsed",
    from_json(col("_raw"), rough_schema)
)

# %%
df_bronze_copy.show(5)
# Out:
# +--------------------+-----------+---------+-------------------+--------------------+----------------+-------------+--------------------+------------+--------------------+--------------------+
# |            Computer|Description|EventCode|               User|                _raw|           _time|cribl_breaker|          cribl_pipe|        host|              source|          raw_parsed|
# +--------------------+-----------+---------+-------------------+--------------------+----------------+-------------+--------------------+------------+--------------------+--------------------+
# |win-host-ctus-att...|       NULL|       23|NT AUTHORITY\SYSTEM|{"Name":"'Microso...|1.674818387593E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|{2023-01-27 11:19...|
# |win-dc-ctus-attac...|       NULL|       23|NT AUTHORITY\SYSTEM|{"Name":"'Microso...|1.674818387419E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|{2023-01-27 11:19...|
# |win-host-ctus-att...|       NULL|       23|NT AUTHORITY\SYSTEM|{"Name":"'Microso...|1.674818387009E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|{2023-01-27 11:19...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387249E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|{2023-01-27 11:19...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387069E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|{2023-01-27 11:19...|
# +--------------------+-----------+---------+-------------------+--------------------+----------------+-------------+--------------------+------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df_silver = df_bronze_copy.select(
    #outer
    col("Computer"),
    col("EventCode"),
    col("User"),
    col("_time"),
    col("source"),
    #inner
    col("raw_parsed.UtcTime").alias("UtcTime"),
    col("raw_parsed.Image").alias("Image"),
    col("raw_parsed.ProcessId").alias("ProcessId"),
    col("raw_parsed.CommandLine").alias("CommandLine"),
    col("raw_parsed.ParentImage").alias("ParentImage"),
    col("raw_parsed.TargetFilename").alias("TargetFilename"),
    col("raw_parsed.QueryName").alias("QueryName"),
    col("raw_parsed.SourceImage").alias("SourceImage"),
    col("raw_parsed.TargetImage").alias("TargetImage"),
    col("raw_parsed.Hashes").alias("Hashes")
    
)

# %%
#df_flat.show(5)

# %%
df_silver.createOrReplaceTempView("sysmon_silver")

# %%
# Provided PySpark SQL Example
spark.sql("""
SELECT *
FROM sysmon_silver
LIMIT 5
""").show()
# Out:
# +--------------------+---------+-------------------+----------------+--------------------+--------------------+--------------------+---------+-----------+-----------+--------------------+---------+--------------------+--------------------+--------------------+
# |            Computer|EventCode|               User|           _time|              source|             UtcTime|               Image|ProcessId|CommandLine|ParentImage|      TargetFilename|QueryName|         SourceImage|         TargetImage|              Hashes|
# +--------------------+---------+-------------------+----------------+--------------------+--------------------+--------------------+---------+-----------+-----------+--------------------+---------+--------------------+--------------------+--------------------+
# |win-host-ctus-att...|       23|NT AUTHORITY\SYSTEM|1.674818387593E9|/tmp/cribldata/in...|2023-01-27 11:19:...|C:\Program Files\...|     3764|       NULL|       NULL|C:\Program Files\...|     NULL|                NULL|                NULL|MD5=5A621B8FAD832...|
# |win-dc-ctus-attac...|       23|NT AUTHORITY\SYSTEM|1.674818387419E9|/tmp/cribldata/in...|2023-01-27 11:19:...|C:\Program Files\...|     3928|       NULL|       NULL|C:\Program Files\...|     NULL|                NULL|                NULL|MD5=7023EAC74833A...|
# |win-host-ctus-att...|       23|NT AUTHORITY\SYSTEM|1.674818387009E9|/tmp/cribldata/in...|2023-01-27 11:19:...|C:\Program Files\...|     1880|       NULL|       NULL|C:\ProgramData\Am...|     NULL|                NULL|                NULL|MD5=97EF2A570B75C...|
# |win-dc-ctus-attac...|       10|               NULL|1.674818387249E9|/tmp/cribldata/in...|2023-01-27 11:19:...|                NULL|     NULL|       NULL|       NULL|                NULL|     NULL|C:\Program Files\...|C:\Program Files\...|                NULL|
# |win-dc-ctus-attac...|       10|               NULL|1.674818387069E9|/tmp/cribldata/in...|2023-01-27 11:19:...|                NULL|     NULL|       NULL|       NULL|                NULL|     NULL|C:\Windows\system...|C:\Program Files\...|                NULL|
# +--------------------+---------+-------------------+----------------+--------------------+--------------------+--------------------+---------+-----------+-----------+--------------------+---------+--------------------+--------------------+--------------------+

# %% [markdown]
# ## Part 2: Detection Engineering

# %% [markdown]
# ### Hypothesis
# - *Adversaries may send spearphishing emails with a malicious attachment in an attempt to gain access to victim systems.*
# - *A threat actor can leverage Microsoft Office applications against users on Windows endpoints through phishing to make potentially malicious web calls.*
# - ***Windows Endpoints forwarding DNS activity via sysmon logs** to a data orchestration platform like Cribl would be utilized to identify this activity.*
#
# Preferably using either PySpark or SQL, create a query or queries that will prove the detection hypothesis.
# - [ ] Output the result of this query in the notebook with a new dataframe
# - [ ] Select columns based on what is applicable to an analyst during triage

# %% [markdown]
# ### Notes
#
#
# -
# - fields
# - no sender field
# - no domain field
# - identify windows endpoint forwarding DNS activity via sysmon logs to a 'crible'
#    - sysmon eventID 22
#       - *'DNS Queries made by any process on a Windows machine'*
# - look for external DNS connection from newly started process
# -
# - sysmon process start
# -

# %%
# DNS sysmon Events
spark.sql("""
SELECT Computer, EventCode, source, Image, QueryName
FROM sysmon_silver
WHERE 
    EventCode = 22
""").show(truncate = False)
# Out:
# +------------------------------+---------+---------------------------------------------------+------------------------------------------------------------------------------+---------------------------------+
# |Computer                      |EventCode|source                                             |Image                                                                         |QueryName                        |
# +------------------------------+---------+---------------------------------------------------+------------------------------------------------------------------------------+---------------------------------+
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Temp\OfficeSetup.exe                                                       |ecs.office.com                   |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Windows\System32\svchost.exe                                               |f.c2r.ts.cdn.office.net          |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Common Files\Microsoft Shared\ClickToRun\OfficeClickToRun.exe|f.c2r.ts.cdn.office.net          |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Common Files\Microsoft Shared\ClickToRun\OfficeClickToRun.exe|ecs.office.com                   |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Common Files\Microsoft Shared\ClickToRun\OfficeClickToRun.exe|ecs.office.com                   |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Common Files\microsoft shared\ClickToRun\OfficeClickToRun.exe|f.c2r.ts.cdn.office.net          |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Windows\System32\svchost.exe                                               |oneclient.sfx.ms                 |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|&lt;unknown process&gt;                                                       |ecs.office.com                   |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |www.mediafire.com                |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |support.content.office.net       |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |ecs.office.com                   |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |augloop.office.com               |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |binaries.templates.cdn.office.net|
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |metadata.templates.cdn.office.net|
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |messaging.lifecycle.office.com   |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE                   |uci.cdn.office.net               |
# +------------------------------+---------+---------------------------------------------------+------------------------------------------------------------------------------+---------------------------------+

# %%
# excluding expected MS destinations
spark.sql("""
SELECT Computer, EventCode, source, Image, QueryName
FROM sysmon_silver
WHERE 
    EventCode = 22
    AND QueryName NOT LIKE '%.office.%'
    AND QueryName NOT LIKE '%microsoft%'
""").show(truncate = False)
# Out:
# +------------------------------+---------+---------------------------------------------------+-----------------------------------------------------------+-----------------+
# |Computer                      |EventCode|source                                             |Image                                                      |QueryName        |
# +------------------------------+---------+---------------------------------------------------+-----------------------------------------------------------+-----------------+
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Windows\System32\svchost.exe                            |oneclient.sfx.ms |
# |win-host-ctus-attack-range-212|22       |/tmp/cribldata/in/sysmon_office_doc_abuses_rels.log|C:\Program Files\Microsoft Office\root\Office16\WINWORD.EXE|www.mediafire.com|
# +------------------------------+---------+---------------------------------------------------+-----------------------------------------------------------+-----------------+

# %%
# all sources are cribl
spark.sql("""
SELECT *
FROM sysmon_silver
WHERE 
    source NOT LIKE '%cribl%'
""").show(truncate = False)
# Out:
# +--------+---------+----+-----+------+-------+-----+---------+-----------+-----------+--------------+---------+-----------+-----------+------+
# |Computer|EventCode|User|_time|source|UtcTime|Image|ProcessId|CommandLine|ParentImage|TargetFilename|QueryName|SourceImage|TargetImage|Hashes|
# +--------+---------+----+-----+------+-------+-----+---------+-----------+-----------+--------------+---------+-----------+-----------+------+
# +--------+---------+----+-----+------+-------+-----+---------+-----------+-----------+--------------+---------+-----------+-----------+------+

# %% [markdown]
# ## Part 3: Additional Steps

# %% [markdown]
# ### Part 3.1: Normalization

# %% [markdown]
# ### Part 3.2: Alert Table

# %% [markdown]
# ### Part 3.3: Enrichment

# %% [markdown]
# ## Summary
#
# Summarize your submission here, comments are helpful to add throughout your code as well.
