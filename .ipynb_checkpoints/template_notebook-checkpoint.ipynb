# %%
# !java -version
# Out:
# openjdk version "17.0.19" 2026-04-21
# OpenJDK Runtime Environment Temurin-17.0.19+10 (build 17.0.19+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.19+10 (build 17.0.19+10, mixed mode)

# %% [markdown]
# # Template Quest Notebook

# %%
# Import neccessary modules, add to this cell as needed
# Provided PySpark examples
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pyspark.sql.functions as F

# %% [markdown]
# ## Part 1: Load the Sample Dataset

# %% [markdown]
# ### Note
# I thought I'd leave in working steps to show process but I've commented out **print**s and **show**s to save clutter

# %%
# Initiate a new Spark session and set the case sensitivity option
spark = (
    SparkSession.builder
        .appName("cyberquest")
        .getOrCreate()
)
spark.conf.set("spark.sql.caseSensitive", True)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/21 21:42:04 WARN Utils: Your hostname, Sams-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.20.6 instead (on interface en0)
# 26/05/21 21:42:04 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/21 21:42:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# TODO: Load the raw data
#    - read from relative path
data_file = 'data/sysmon_spearphish_cribl.json'
df_bronze = spark.read.json(data_file)
#df_bronze.show(10, truncate = False)
# Out:
# +--------------------+-----------+---------+-------------------+--------------------+----------------+-------------+--------------------+------------+--------------------+
# |            Computer|Description|EventCode|               User|                _raw|           _time|cribl_breaker|          cribl_pipe|        host|              source|
# +--------------------+-----------+---------+-------------------+--------------------+----------------+-------------+--------------------+------------+--------------------+
# |win-host-ctus-att...|       NULL|       23|NT AUTHORITY\SYSTEM|{"Name":"'Microso...|1.674818387593E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       23|NT AUTHORITY\SYSTEM|{"Name":"'Microso...|1.674818387419E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-host-ctus-att...|       NULL|       23|NT AUTHORITY\SYSTEM|{"Name":"'Microso...|1.674818387009E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387249E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387069E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387068E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387068E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387067E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387067E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# |win-dc-ctus-attac...|       NULL|       10|               NULL|{"Name":"'Microso...|1.674818387067E9|     fallback|Splunk_UF_Windows...|f2c75b47cbb7|/tmp/cribldata/in...|
# +--------------------+-----------+---------+-------------------+--------------------+----------------+-------------+--------------------+------------+--------------------+
# only showing top 10 rows

# %%
#local copy of first three rows for a bit of manual exploration.
inspectionSample = df_bronze.take(3)
#print(inspectionSample[2][4])
# Out:
# {"Name":"'Microsoft-Windows-Sysmon'","Guid":"'{5770385F-C22A-43E0-BF4C-06F5698FFBD9}'","Version":"5","Level":"4","Task":"23","Opcode":"0","Keywords":"0x8000000000000000","SystemTime":"'2023-01-27T11:19:47.009197600Z'","EventRecordID":"320270","ProcessID":"'1912'","ThreadID":"'2628'","Channel":"Microsoft-Windows-Sysmon/Operational","UserID":"S-1-5-18","RuleName":"-","UtcTime":"2023-01-27 11:19:47.008","ProcessGuid":"{72106695-9B85-63D3-1B00-00000000BD02}","ProcessId":"1880","Image":"C:\\Program Files\\Amazon\\SSM\\amazon-ssm-agent.exe","TargetFilename":"C:\\ProgramData\\Amazon\\SSM\\InstanceData\\i-0f154ddf1aa5a8e8d\\channels\\health\\surveyor-20230127093814-099","Hashes":"MD5=97EF2A570B75C4F95FC69B0D09A2E2A2,SHA256=11396EA313B0ED7E3228C4FA92ABE9D836DB8F416A7A8A28ACC77133025082E7,IMPHASH=00000000000000000000000000000000","IsExecutable":"false","Archived":"true"}

# %%
# TODO: Parse the raw data into something relevant and usable
#   - make fields in _raw usable, flatten into 2D df. 
#      - [x] make rough schema of inner JSON, just useful looking fields.
#          - [ ] if task 2 requires further fields or I miss any I can revisit here.
#      - [x] make copy of bronze_df with another column containing _raw as parsed json from rough schema.
#      - [x] select useful fields from parsed_raw as columns for silver_df.

rough_schema = StructType([
    StructField("UtcTime", StringType(), True),
    StructField("Image", StringType(), True),
    StructField("ProcessId", StringType(), True),
    StructField("CommandLine", StringType(), True),
    StructField("ParentImage", StringType(), True),
    StructField("TargetFilename", StringType(), True),
    StructField("SourceImage", StringType(), True),
    StructField("TargetImage", StringType(), True),
    StructField("QueryName", StringType(), True),
    StructField("Hashes", StringType(), True)
])

df_bronze_copy = df_bronze.withColumn(
    "raw_parsed",
    from_json(col("_raw"), rough_schema)
)

# %%
#df_bronze_copy.show(5)

# %%
df_silver = df_bronze_copy.select(
    #outer
    col("Computer"),
    col("EventCode"),
    col("User"),
    col("_time"),
    #inner
    col("raw_parsed.UtcTime").alias("UtcTime"),
    col("raw_parsed.Image").alias("Image"),
    col("raw_parsed.ProcessId").alias("ProcessId"),
    col("raw_parsed.CommandLine").alias("CommandLine"),
    col("raw_parsed.ParentImage").alias("ParentImage"),
    col("raw_parsed.TargetFilename").alias("TargetFilename"),
    col("raw_parsed.QueryName").alias("QueryName"),
    col("raw_parsed.SourceImage").alias("SourceImage"),
    col("raw_parsed.TargetImage").alias("TargetImage"),
    col("raw_parsed.Hashes").alias("Hashes")
)

# %%
#df_flat.show(5)

# %%
df_silver.createOrReplaceTempView("sysmon_silver")

# %%
# Provided PySpark SQL Example
spark.sql("""
SELECT *
FROM sysmon_silver
LIMIT 5
""").show()
# Out:
# +--------------------+---------+-------------------+----------------+--------------------+--------------------+---------+-----------+-----------+--------------------+---------+--------------------+--------------------+--------------------+
# |            Computer|EventCode|               User|           _time|             UtcTime|               Image|ProcessId|CommandLine|ParentImage|      TargetFilename|QueryName|         SourceImage|         TargetImage|              Hashes|
# +--------------------+---------+-------------------+----------------+--------------------+--------------------+---------+-----------+-----------+--------------------+---------+--------------------+--------------------+--------------------+
# |win-host-ctus-att...|       23|NT AUTHORITY\SYSTEM|1.674818387593E9|2023-01-27 11:19:...|C:\Program Files\...|     3764|       NULL|       NULL|C:\Program Files\...|     NULL|                NULL|                NULL|MD5=5A621B8FAD832...|
# |win-dc-ctus-attac...|       23|NT AUTHORITY\SYSTEM|1.674818387419E9|2023-01-27 11:19:...|C:\Program Files\...|     3928|       NULL|       NULL|C:\Program Files\...|     NULL|                NULL|                NULL|MD5=7023EAC74833A...|
# |win-host-ctus-att...|       23|NT AUTHORITY\SYSTEM|1.674818387009E9|2023-01-27 11:19:...|C:\Program Files\...|     1880|       NULL|       NULL|C:\ProgramData\Am...|     NULL|                NULL|                NULL|MD5=97EF2A570B75C...|
# |win-dc-ctus-attac...|       10|               NULL|1.674818387249E9|2023-01-27 11:19:...|                NULL|     NULL|       NULL|       NULL|                NULL|     NULL|C:\Program Files\...|C:\Program Files\...|                NULL|
# |win-dc-ctus-attac...|       10|               NULL|1.674818387069E9|2023-01-27 11:19:...|                NULL|     NULL|       NULL|       NULL|                NULL|     NULL|C:\Windows\system...|C:\Program Files\...|                NULL|
# +--------------------+---------+-------------------+----------------+--------------------+--------------------+---------+-----------+-----------+--------------------+---------+--------------------+--------------------+--------------------+

# %% [markdown]
# ## Part 2: Detection Engineering

# %% [markdown]
# ## Part 3: Additional Steps

# %% [markdown]
# ### Part 3.1: Normalization

# %% [markdown]
# ### Part 3.2: Alert Table

# %% [markdown]
# ### Part 3.3: Enrichment

# %% [markdown]
# ## Summary
#
# Summarize your submission here, comments are helpful to add throughout your code as well.
